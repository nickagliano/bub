# %% [markdown]
# # Battle Ultra Bot (aka B.U.B.)
#
# ### version 0.0.1

# %% [markdown]
# Notes:
#
# B.U.B. version 0.0.1 uses the following versions:
# * python:  3.7.4
# * tensorflow:  2.0.0 (but casted to v1 compatitbility for now)
# * gym:  0.15.4
# * numpy:  1.18.0
#
# We recommend checking the output of the next cell and comparing it to the versions listed above.
#
# -----

# %%
# import packages and check versions

import tensorflow.compat.v1 as tf
import gym
import random
import platform
from collections import deque
import numpy as np
print("python: ", platform.python_version())
print("tensorflow: ", tf.__version__)
print("gym: ", gym.__version__)
print("numpy: ", np.__version__)
# Out:
# python:  3.7.4
# tensorflow:  2.0.0
# gym:  0.15.4
# numpy:  1.18.0

# %%
# build custom pokemon environment
env_name = "Pokemon-v0"

env = gym.make(env_name)

# declare constants
numMoves = 821
numNonVolatileStatuses = 7
numVolatileStatuses = 57
numTypes = 18
numItems = 413
numAbilities = 262
numPokemon = 1198

print("observation space: ", env.observation_space)
print("upper limit: ", env.observation_space.high)
print("lower limit: ", env.observation_space.low)
print("\nAction space: ", env.action_space)

tf.disable_eager_execution() # for compatibility issues
# Out:
# observation space:  Box(4,)
# upper limit:  [4.8000002e+00 3.4028235e+38 4.1887903e-01 3.4028235e+38]
# lower limit:  [-4.8000002e+00 -3.4028235e+38 -4.1887903e-01 -3.4028235e+38]
#
# Action space:  Discrete(2)

# %%
# declare and initialize the QNetwork

class QNetwork():
    def __init__(self, state_dim, action_size):
        self.state_in = tf.placeholder(tf.float32, shape=[None, *state_dim])
        self.action_in = tf.placeholder(tf.int32, shape=[None])
        self.q_target_in = tf.placeholder(tf.float32, shape=[None])
        action_one_hot = tf.one_hot(self.action_in, depth=action_size)
        
        self.hidden1 = tf.layers.dense(self.state_in, 100, activation=tf.nn.relu)
        self.q_state = tf.layers.dense(self.hidden1, action_size, activation=None)
        self.q_state_action = tf.reduce_sum(tf.multiply(self.q_state, action_one_hot), axis=1)
        
        self.loss = tf.reduce_mean(tf.square(self.q_state_action - self.q_target_in))
        self.optimizer = tf.train.AdamOptimizer(learning_rate=0.001).minimize(self.loss)
      
    def update_model(self, session, state, action, q_target):
        feed = {self.state_in: state, self.action_in: action, self.q_target_in: q_target}
        session.run(self.optimizer, feed_dict=feed)
    
    def get_q_state(self, session, state):
        q_state = session.run(self.q_state, feed_dict={self.state_in: state})
        return q_state

# %% [markdown]
# #### A small, yet important addition: the ReplayBuffer( ) class
#
# * exists bc
# * does x, y, z

# %%
class ReplayBuffer():
    def __init__(self, maxlen):
        self.buffer = deque(maxlen=maxlen)
        
    def add(self, experience):
        self.buffer.append(experience)
        
    def sample(self, batch_size):
        sample_size = min(len(self.buffer), batch_size)
        samples = random.choices(self.buffer, k=sample_size)
        return map(list, zip(*samples))

# %% [markdown]
# ## The DQNAgent( ) class
#
# The learning agent / also known as the deep QNetwork agent is the mechanism of learning for the QNetwork.
# * agent needs to select the action with the highest predicted Q value
# *
#
# #### \_\_init\_\_(self, env):
# Desc.
# * info
# * info
#
# #### get_action(self, state):
# Desc.
# * info
# * info
#
# #### train(self, state, action, next_state, reward, done):
# Desc.
# * info
# * info
#
# #### \_\_del\_\_(self):
# Desc.
# * info
# * info

# %%
class DQNAgent():
    def __init__(self, env):
        self.state_dim = env.observation_space.shape
        self.action_size = env.action_space.n
        self.q_network = QNetwork(self.state_dim, self.action_size)
        self.replay_buffer = ReplayBuffer(maxlen=10000)
        self.gamma = 0.97
        self.eps = 1.0
        self.sess = tf.Session()
        self.sess.run(tf.global_variables_initializer())
        
    def get_action(self, state):
        q_state = self.q_network.get_q_state(self.sess, [state])
        action_greedy = np.argmax(q_state)
        action_random = np.random.randint(self.action_size)
        action = action_random if random.random() < self.eps else action_greedy
        return action
    
    def train(self, state, action, next_state, reward, done):
        self.replay_buffer.add((state, action, next_state, reward, done))
        states, actions, next_states, rewards, dones = self.replay_buffer.sample(50)
        q_next_states = self.q_network.get_q_state(self.sess, next_states)
        q_next_states[dones] = np.zeros([self.action_size])
        q_targets = rewards + self.gamma * np.max(q_next_states, axis=1)
        self.q_network.update_model(self.sess, states, actions, q_targets)
        
        if done: self.eps = max(0.1, 0.99*self.eps)
    
    def __del__(self):
        self.sess.close()

# %% [markdown]
# ### Putting it all together, B.U.B. plays and learns

# %%
agent = DQNAgent(env)
num_episodes = 400

for ep in range(num_episodes):
    state = env.reset()
    total_reward = 0
    done = False
    while not done:
        action = agent.get_action(state)
        next_state, reward, done, info = env.step(action)
        agent.train(state, action, next_state, reward, done)
        env.render()
        total_reward += reward
        state = next_state
        
    print("Episode: {}, total_reward: {:.2f}".format(ep, total_reward))
# Out:
# WARNING:tensorflow:From <ipython-input-3-d8fce2b1a3cf>:10: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.Dense instead.
# WARNING:tensorflow:From /Users/nick/Documents/bub/ai/venv/lib/python3.7/site-packages/tensorflow_core/python/layers/core.py:187: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From /Users/nick/Documents/bub/ai/venv/lib/python3.7/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Episode: 0, total_reward: 35.00
# Episode: 1, total_reward: 13.00
# Episode: 2, total_reward: 11.00
# Episode: 3, total_reward: 52.00
# Episode: 4, total_reward: 39.00
# Episode: 5, total_reward: 9.00
# Episode: 6, total_reward: 15.00
# Episode: 7, total_reward: 12.00
# Episode: 8, total_reward: 29.00
# Episode: 9, total_reward: 18.00
# Episode: 10, total_reward: 16.00
# Episode: 11, total_reward: 12.00
# Episode: 12, total_reward: 9.00
# Episode: 13, total_reward: 56.00
# Episode: 14, total_reward: 17.00
# Episode: 15, total_reward: 10.00
# Episode: 16, total_reward: 31.00
# Episode: 17, total_reward: 11.00
# Episode: 18, total_reward: 16.00
# Episode: 19, total_reward: 13.00
# Episode: 20, total_reward: 20.00
# Episode: 21, total_reward: 14.00
# Episode: 22, total_reward: 18.00
# Episode: 23, total_reward: 14.00
# Episode: 24, total_reward: 18.00
# Episode: 25, total_reward: 20.00
# Episode: 26, total_reward: 15.00
# Episode: 27, total_reward: 12.00
# Episode: 28, total_reward: 21.00
# Episode: 29, total_reward: 9.00
# Episode: 30, total_reward: 17.00
# Episode: 31, total_reward: 10.00
# Episode: 32, total_reward: 17.00
# Episode: 33, total_reward: 16.00
# Episode: 34, total_reward: 21.00
# Episode: 35, total_reward: 15.00
# Episode: 36, total_reward: 15.00
# Episode: 37, total_reward: 12.00
# Episode: 38, total_reward: 18.00
# Episode: 39, total_reward: 13.00
# Episode: 40, total_reward: 32.00
# Episode: 41, total_reward: 23.00
# Episode: 42, total_reward: 11.00
# Episode: 43, total_reward: 11.00
# Episode: 44, total_reward: 10.00
# Episode: 45, total_reward: 20.00
# Episode: 46, total_reward: 10.00
# Episode: 47, total_reward: 16.00
# Episode: 48, total_reward: 25.00
# Episode: 49, total_reward: 31.00
# Episode: 50, total_reward: 11.00
# Episode: 51, total_reward: 20.00
# Episode: 52, total_reward: 13.00
# Episode: 53, total_reward: 11.00
# Episode: 54, total_reward: 14.00
# Episode: 55, total_reward: 14.00
# Episode: 56, total_reward: 10.00
# Episode: 57, total_reward: 13.00
# Episode: 58, total_reward: 11.00
# Episode: 59, total_reward: 13.00
# Episode: 60, total_reward: 11.00
# Episode: 61, total_reward: 17.00
# Episode: 62, total_reward: 23.00
# Episode: 63, total_reward: 72.00
# Episode: 64, total_reward: 47.00
# Episode: 65, total_reward: 40.00
# Episode: 66, total_reward: 41.00
# Episode: 67, total_reward: 35.00
# Episode: 68, total_reward: 34.00
# Episode: 69, total_reward: 20.00
# Episode: 70, total_reward: 41.00
# Episode: 71, total_reward: 63.00
# Episode: 72, total_reward: 69.00
# Episode: 73, total_reward: 61.00
# Episode: 74, total_reward: 69.00
# Episode: 75, total_reward: 117.00
# Episode: 76, total_reward: 53.00
# Episode: 77, total_reward: 50.00
# Episode: 78, total_reward: 73.00
# Episode: 79, total_reward: 69.00
# Episode: 80, total_reward: 34.00
# Episode: 81, total_reward: 57.00
# Episode: 82, total_reward: 53.00
# Episode: 83, total_reward: 41.00
# Episode: 84, total_reward: 47.00
# Episode: 85, total_reward: 46.00
# Episode: 86, total_reward: 32.00
# Episode: 87, total_reward: 64.00
# Episode: 88, total_reward: 65.00
# Episode: 89, total_reward: 50.00
# Episode: 90, total_reward: 37.00
# Episode: 91, total_reward: 165.00
# Episode: 92, total_reward: 146.00
# Episode: 93, total_reward: 57.00
# Episode: 94, total_reward: 109.00
# Episode: 95, total_reward: 102.00
# Episode: 96, total_reward: 57.00
# Episode: 97, total_reward: 57.00
# Episode: 98, total_reward: 72.00
# Episode: 99, total_reward: 130.00
# Episode: 100, total_reward: 69.00
# Episode: 101, total_reward: 70.00
# Episode: 102, total_reward: 90.00
# Episode: 103, total_reward: 86.00
# Episode: 104, total_reward: 98.00
# Episode: 105, total_reward: 110.00
# Episode: 106, total_reward: 141.00
# Episode: 107, total_reward: 190.00
# Episode: 108, total_reward: 200.00
# Episode: 109, total_reward: 200.00
# Episode: 110, total_reward: 147.00
# Episode: 111, total_reward: 179.00
# Episode: 112, total_reward: 200.00
# Episode: 113, total_reward: 200.00
# Episode: 114, total_reward: 200.00
# Episode: 115, total_reward: 200.00
# Episode: 116, total_reward: 200.00
# Episode: 117, total_reward: 200.00
# Episode: 118, total_reward: 200.00
# Episode: 119, total_reward: 200.00
# Episode: 120, total_reward: 200.00
# Episode: 121, total_reward: 200.00
# Episode: 122, total_reward: 200.00
# Episode: 123, total_reward: 200.00
# Episode: 124, total_reward: 200.00
# Episode: 125, total_reward: 200.00
# Episode: 126, total_reward: 200.00
# Episode: 127, total_reward: 200.00
# Episode: 128, total_reward: 200.00
# Episode: 129, total_reward: 200.00
# Episode: 130, total_reward: 88.00
# Episode: 131, total_reward: 200.00
# Episode: 132, total_reward: 200.00
# Episode: 133, total_reward: 200.00
# Episode: 134, total_reward: 200.00
# Episode: 135, total_reward: 200.00
# Episode: 136, total_reward: 200.00
# Episode: 137, total_reward: 200.00
# Episode: 138, total_reward: 200.00
# Episode: 139, total_reward: 200.00
# Episode: 140, total_reward: 200.00
# Episode: 141, total_reward: 200.00
# Episode: 142, total_reward: 200.00
# Episode: 143, total_reward: 200.00
# Episode: 144, total_reward: 200.00
# Episode: 145, total_reward: 200.00
# Episode: 146, total_reward: 200.00
# Episode: 147, total_reward: 200.00
# Episode: 148, total_reward: 200.00
# Episode: 149, total_reward: 200.00
# Episode: 150, total_reward: 200.00
# Episode: 151, total_reward: 200.00
# Episode: 152, total_reward: 200.00
# Episode: 153, total_reward: 200.00
# Episode: 154, total_reward: 200.00
# Episode: 155, total_reward: 200.00
# Episode: 156, total_reward: 200.00
# Episode: 157, total_reward: 200.00
# Episode: 158, total_reward: 200.00
# Episode: 159, total_reward: 200.00
# Episode: 160, total_reward: 200.00
# Episode: 161, total_reward: 200.00
# Episode: 162, total_reward: 200.00
# Episode: 163, total_reward: 200.00
# Episode: 164, total_reward: 200.00
# Episode: 165, total_reward: 200.00
# Episode: 166, total_reward: 200.00
# Episode: 167, total_reward: 200.00
# Episode: 168, total_reward: 200.00
# Episode: 169, total_reward: 200.00
# Episode: 170, total_reward: 200.00
# Episode: 171, total_reward: 200.00
# Episode: 172, total_reward: 200.00
# Episode: 173, total_reward: 200.00
# Episode: 174, total_reward: 200.00
# Episode: 175, total_reward: 200.00
# Episode: 176, total_reward: 200.00
# Episode: 177, total_reward: 200.00
# Episode: 178, total_reward: 200.00
# Episode: 179, total_reward: 200.00
# Episode: 180, total_reward: 200.00
# Episode: 181, total_reward: 200.00
# Episode: 182, total_reward: 200.00
# Episode: 183, total_reward: 200.00
# Episode: 184, total_reward: 200.00
# Episode: 185, total_reward: 200.00
# Episode: 186, total_reward: 200.00
# Episode: 187, total_reward: 200.00
# Episode: 188, total_reward: 200.00
# Episode: 189, total_reward: 200.00
# Episode: 190, total_reward: 200.00
# Episode: 191, total_reward: 200.00
# Episode: 192, total_reward: 200.00
# Episode: 193, total_reward: 200.00
# Episode: 194, total_reward: 200.00
# Episode: 195, total_reward: 200.00
# Episode: 196, total_reward: 200.00
# Episode: 197, total_reward: 200.00
# Episode: 198, total_reward: 200.00
# Episode: 199, total_reward: 200.00
# Episode: 200, total_reward: 200.00
# Episode: 201, total_reward: 200.00
# Episode: 202, total_reward: 200.00
# Episode: 203, total_reward: 200.00
# Episode: 204, total_reward: 9.00
# Episode: 205, total_reward: 200.00
# Episode: 206, total_reward: 200.00
# Episode: 207, total_reward: 200.00
# Episode: 208, total_reward: 200.00
# Episode: 209, total_reward: 200.00
# Episode: 210, total_reward: 200.00
# Episode: 211, total_reward: 200.00
# Episode: 212, total_reward: 200.00
# Episode: 213, total_reward: 200.00
# Episode: 214, total_reward: 200.00
# Episode: 215, total_reward: 200.00
# Episode: 216, total_reward: 200.00
# Episode: 217, total_reward: 200.00
# Episode: 218, total_reward: 200.00
# Episode: 219, total_reward: 200.00
# Episode: 220, total_reward: 200.00
# Episode: 221, total_reward: 200.00
# Episode: 222, total_reward: 200.00
# Episode: 223, total_reward: 200.00
# Episode: 224, total_reward: 200.00
# Episode: 225, total_reward: 200.00
# Episode: 226, total_reward: 200.00
# Episode: 227, total_reward: 200.00
# Episode: 228, total_reward: 200.00
# Episode: 229, total_reward: 200.00
# Episode: 230, total_reward: 200.00
# Episode: 231, total_reward: 200.00
# Episode: 232, total_reward: 200.00
# Episode: 233, total_reward: 200.00
# Episode: 234, total_reward: 200.00
# Episode: 235, total_reward: 200.00
# Episode: 236, total_reward: 200.00
# Episode: 237, total_reward: 200.00
# Episode: 238, total_reward: 200.00
# Episode: 239, total_reward: 200.00
# Episode: 240, total_reward: 200.00
# Episode: 241, total_reward: 200.00
# Episode: 242, total_reward: 200.00
# Episode: 243, total_reward: 200.00
# Episode: 244, total_reward: 200.00
# Episode: 245, total_reward: 200.00
# Episode: 246, total_reward: 200.00
# Episode: 247, total_reward: 200.00
# Episode: 248, total_reward: 200.00
# Episode: 249, total_reward: 200.00
# Episode: 250, total_reward: 200.00
# Episode: 251, total_reward: 200.00
# Episode: 252, total_reward: 106.00
# Episode: 253, total_reward: 156.00
# Episode: 254, total_reward: 200.00
# Episode: 255, total_reward: 63.00
# Episode: 256, total_reward: 200.00
# Episode: 257, total_reward: 49.00
# Episode: 258, total_reward: 72.00
# Episode: 259, total_reward: 86.00
# Episode: 260, total_reward: 17.00
# Episode: 261, total_reward: 187.00
# Episode: 262, total_reward: 190.00
# Episode: 263, total_reward: 200.00
# Episode: 264, total_reward: 200.00
# Episode: 265, total_reward: 200.00
# Episode: 266, total_reward: 200.00
# Episode: 267, total_reward: 200.00
# Episode: 268, total_reward: 200.00
# Episode: 269, total_reward: 200.00
# Episode: 270, total_reward: 200.00
# Episode: 271, total_reward: 200.00
# Episode: 272, total_reward: 200.00
# Episode: 273, total_reward: 200.00
# Episode: 274, total_reward: 200.00
# Episode: 275, total_reward: 200.00
# Episode: 276, total_reward: 200.00
# Episode: 277, total_reward: 200.00
# Episode: 278, total_reward: 200.00
# Episode: 279, total_reward: 200.00
# Episode: 280, total_reward: 200.00
# Episode: 281, total_reward: 200.00
# Episode: 282, total_reward: 200.00
# Episode: 283, total_reward: 200.00
# Episode: 284, total_reward: 200.00
# Episode: 285, total_reward: 200.00
# Episode: 286, total_reward: 200.00
# Episode: 287, total_reward: 200.00
# Episode: 288, total_reward: 200.00
# Episode: 289, total_reward: 200.00
# Episode: 290, total_reward: 200.00
# Episode: 291, total_reward: 200.00
# Episode: 292, total_reward: 200.00
# Episode: 293, total_reward: 200.00
# Episode: 294, total_reward: 200.00
# Episode: 295, total_reward: 200.00
# Episode: 296, total_reward: 200.00
# Episode: 297, total_reward: 200.00
# Episode: 298, total_reward: 200.00
# Episode: 299, total_reward: 200.00
# Episode: 300, total_reward: 200.00
# Episode: 301, total_reward: 200.00
# Episode: 302, total_reward: 200.00
# Episode: 303, total_reward: 200.00
# Episode: 304, total_reward: 200.00
# Episode: 305, total_reward: 200.00
# Episode: 306, total_reward: 200.00

# %%
env.close()
